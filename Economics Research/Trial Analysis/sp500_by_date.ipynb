# %% [markdown]
# # S&P 500 by date
#
# Get snapshot of S&P 500 components at a given date

# %%
from datetime import datetime
import os
import shutil
import pandas as pd

pd.options.mode.chained_assignment = None  # default='warn'
pd.set_option('display.max_rows', 600)

# -*- encoding: utf-8 -*-
# %matplotlib inline

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# Date to use for snapshot of S&P 500 components.
snap_shot = '2008-01-01'

# %%
def get_table(filename):

    if os.path.isfile(filename):
        df = pd.read_csv(filename, index_col='date')
        return df

# %%
filename = 'S&P 500 Historical Components & Changes(04-25-2023).csv'
df = get_table(filename)
df.tail()
# Out:
#                                                       tickers
# date
# 2022-12-19  A,AAL,AAP,AAPL,ABBV,ABC,ABT,ACGL,ACN,ADBE,ADI,...
# 2022-12-22  A,AAL,AAP,AAPL,ABBV,ABC,ABT,ACGL,ACN,ADBE,ADI,...
# 2023-01-04  A,AAL,AAP,AAPL,ABBV,ABC,ABT,ACGL,ACN,ADBE,ADI,...
# 2023-03-15  A,AAL,AAP,AAPL,ABBV,ABC,ABT,ACGL,ACN,ADBE,ADI,...
# 2023-03-20  A,AAL,AAP,AAPL,ABBV,ABC,ABT,ACGL,ACN,ADBE,ADI,...

# %%
# Convert ticker column from csv to list, then sort.
df['tickers'] = df['tickers'].apply(lambda x: sorted(x.split(',')))
df.tail()
# Out:
#                                                       tickers
# date
# 2022-12-19  [A, AAL, AAP, AAPL, ABBV, ABC, ABT, ACGL, ACN,...
# 2022-12-22  [A, AAL, AAP, AAPL, ABBV, ABC, ABT, ACGL, ACN,...
# 2023-01-04  [A, AAL, AAP, AAPL, ABBV, ABC, ABT, ACGL, ACN,...
# 2023-03-15  [A, AAL, AAP, AAPL, ABBV, ABC, ABT, ACGL, ACN,...
# 2023-03-20  [A, AAL, AAP, AAPL, ABBV, ABC, ABT, ACGL, ACN,...

# %%
# Number of symbols in the first row.
l = list(df['tickers'].head(1))[0]
len(l)
# Out:
# 487

# %%
# Get the synbols on snap_shot date by filtering df by rows before or on the snap_shot date,
# then picking the last row.
df2 = df[df.index <= snap_shot]
last_row = df2.tail(1)
last_row
# Out:
#                                                       tickers
# date
# 2007-12-31  [A, AABA, AAPL, ABC, ABI, ABKFQ, ABT, ACAS, AC...

# %%
past = last_row['tickers'][0]
print('*'*40, f'S&P 500 on {snap_shot}', '*'*40)
print(past)
# Out:
# **************************************** S&P 500 on 2008-01-01 ****************************************
# ['A', 'AABA', 'AAPL', 'ABC', 'ABI', 'ABKFQ', 'ABT', 'ACAS', 'ACS', 'ADBE', 'ADI', 'ADM', 'ADP', 'ADSK', 'AEE', 'AEP', 'AES', 'AET', 'AFL', 'AGN', 'AIG', 'AIV', 'AIZ', 'AKAM', 'ALL', 'ALTR', 'AMAT', 'AMD', 'AMGN', 'AMP', 'AMT', 'AMZN', 'AN', 'ANDV', 'ANF', 'ANTM', 'AON', 'APA', 'APC', 'APD', 'APOL', 'ARNC', 'ASH', 'ATI', 'AVB', 'AVP', 'AVY', 'AW', 'AXP', 'AYE', 'AZO', 'BA', 'BAC', 'BAX', 'BBBY', 'BBT', 'BBY', 'BC', 'BCR', 'BDK', 'BDX', 'BEAM', 'BEN', 'BF.B', 'BHGE', 'BIG', 'BIIB', 'BJS', 'BK', 'BLL', 'BMC', 'BMS', 'BMY', 'BNI', 'BRCM', 'BRL', 'BSC', 'BSX', 'BTUUQ', 'BUD', 'BXP', 'C', 'CA', 'CAG', 'CAH', 'CAT', 'CB', 'CBE', 'CBH', 'CBRE', 'CBS', 'CCE', 'CCL', 'CCTYQ', 'CCU', 'CEG', 'CELG', 'CFC', 'CHK', 'CHRW', 'CI', 'CIEN', 'CINF', 'CITGQ', 'CL', 'CLX', 'CMA', 'CMCSA', 'CME', 'CMI', 'CMS', 'CNP', 'CNX', 'COF', 'COL', 'COP', 'COST', 'COV', 'CPB', 'CPWR', 'CSCO', 'CSX', 'CTAS', 'CTL', 'CTSH', 'CTX', 'CTXS', 'CVG', 'CVH', 'CVS', 'CVX', 'D', 'DD', 'DDR', 'DDS', 'DE', 'DELL', 'DF', 'DFS', 'DGX', 'DHI', 'DHR', 'DIS', 'DOV', 'DOW', 'DRI', 'DTE', 'DTV', 'DUK', 'DVN', 'DXC', 'DYN', 'EA', 'EBAY', 'ECL', 'ED', 'EDS', 'EFX', 'EIX', 'EKDKQ', 'EL', 'EMC', 'EMN', 'EMR', 'EOG', 'EP', 'EQ', 'EQR', 'ESRX', 'ESV', 'ETFC', 'ETN', 'ETR', 'EXC', 'EXPD', 'EXPE', 'F', 'FCX', 'FDO', 'FDX', 'FE', 'FHN', 'FII', 'FIS', 'FISV', 'FITB', 'FLR', 'FMCC', 'FNMA', 'FOXA', 'FRX', 'FTR', 'GAS', 'GD', 'GE', 'GENZ', 'GGP', 'GHC', 'GILD', 'GIS', 'GLW', 'GME', 'GNW', 'GOOGL', 'GPC', 'GPS', 'GR', 'GS', 'GT', 'GWW', 'HAL', 'HAR', 'HAS', 'HBAN', 'HCBK', 'HD', 'HES', 'HET', 'HIG', 'HNZ', 'HOG', 'HON', 'HOT', 'HPC', 'HPQ', 'HRB', 'HSH', 'HSP', 'HST', 'HSY', 'HUM', 'IAC', 'IBM', 'ICE', 'IFF', 'IGT', 'INTC', 'INTU', 'IP', 'IPG', 'IR', 'ITT', 'ITW', 'JAVA', 'JBL', 'JCI', 'JCP', 'JEC', 'JEF', 'JNJ', 'JNPR', 'JNS', 'JNY', 'JPM', 'JWN', 'K', 'KATE', 'KBH', 'KEY', 'KG', 'KIM', 'KLAC', 'KMB', 'KO', 'KR', 'KSS', 'L', 'LB', 'LEG', 'LEHMQ', 'LEN', 'LH', 'LLL', 'LLTC', 'LLY', 'LM', 'LMT', 'LNC', 'LOW', 'LSI', 'LUV', 'LXK', 'M', 'MAR', 'MAS', 'MAT', 'MBI', 'MCD', 'MCHP', 'MCK', 'MCO', 'MDLZ', 'MDP', 'MDT', 'MER', 'MET', 'MHS', 'MI', 'MIL', 'MKC', 'MMC', 'MMM', 'MO', 'MOLX', 'MON', 'MRK', 'MRO', 'MS', 'MSFT', 'MSI', 'MTB', 'MTG', 'MTLQQ', 'MTW', 'MU', 'MUR', 'MWV', 'MWW', 'MYL', 'NBL', 'NBR', 'NCC', 'NE', 'NEE', 'NEM', 'NI', 'NKE', 'NOC', 'NOV', 'NOVL', 'NSC', 'NSM', 'NTAP', 'NTRS', 'NUE', 'NVDA', 'NVLS', 'NWL', 'NYT', 'NYX', 'ODP', 'OMC', 'OMX', 'ORCL', 'OXY', 'PAYX', 'PBG', 'PBI', 'PCAR', 'PCG', 'PCL', 'PCP', 'PDCO', 'PEG', 'PEP', 'PFE', 'PFG', 'PG', 'PGN', 'PGR', 'PH', 'PHM', 'PKI', 'PLD', 'PLL', 'PNC', 'PNW', 'POM', 'PPG', 'PPL', 'PRU', 'PSA', 'PTV', 'PX', 'Q', 'QCOM', 'QLGC', 'R', 'RAI', 'RDC', 'RF', 'RHI', 'RIG', 'RL', 'ROH', 'ROK', 'RRC', 'RRD', 'RSHCQ', 'RTN', 'RX', 'S', 'SAF', 'SBUX', 'SCHW', 'SE', 'SEE', 'SGP', 'SHLD', 'SHW', 'SIAL', 'SII', 'SLB', 'SLM', 'SNA', 'SNDK', 'SNV', 'SO', 'SOV', 'SPG', 'SPGI', 'SPLS', 'SRE', 'SSP', 'STI', 'STJ', 'STR', 'STT', 'STZ', 'SUN', 'SUNEQ', 'SVU', 'SWK', 'SWY', 'SYK', 'SYMC', 'SYY', 'T', 'TAP', 'TDC', 'TE', 'TEG', 'TEL', 'TER', 'TEX', 'TGNA', 'TGT', 'THC', 'TIE', 'TIF', 'TJX', 'TLAB', 'TMK', 'TMO', 'TPR', 'TROW', 'TRV', 'TSN', 'TT', 'TWX', 'TXN', 'TXT', 'UIS', 'UNH', 'UNM', 'UNP', 'UPS', 'USB', 'UST', 'UTX', 'VAR', 'VFC', 'VIAB', 'VIAV', 'VLO', 'VMC', 'VNO', 'VRSN', 'VZ', 'WAMUQ', 'WAT', 'WB', 'WBA', 'WEN', 'WFC', 'WFM', 'WFT', 'WHR', 'WIN', 'WM', 'WMB', 'WMT', 'WU', 'WWY', 'WY', 'WYE', 'WYND', 'X', 'XEL', 'XL', 'XLNX', 'XOM', 'XRX', 'XTO', 'YUM', 'ZBH', 'ZION']

# %%
df2 = pd.DataFrame(past, columns = ['Ticker'])
df2
# Out:
#     Ticker
# 0        A
# 1     AABA
# 2     AAPL
# 3      ABC
# 4      ABI
# 5    ABKFQ
# 6      ABT
# 7     ACAS
# 8      ACS
# 9     ADBE
# 10     ADI
# 11     ADM
# 12     ADP
# 13    ADSK
# 14     AEE
# 15     AEP
# 16     AES
# 17     AET
# 18     AFL
# 19     AGN
# 20     AIG
# 21     AIV
# 22     AIZ
# 23    AKAM
# 24     ALL
# 25    ALTR
# 26    AMAT
# 27     AMD
# 28    AMGN
# 29     AMP
# 30     AMT
# 31    AMZN
# 32      AN
# 33    ANDV
# 34     ANF
# 35    ANTM
# 36     AON
# 37     APA
# 38     APC
# 39     APD
# 40    APOL
# 41    ARNC
# 42     ASH
# 43     ATI
# 44     AVB
# 45     AVP
# 46     AVY
# 47      AW
# 48     AXP
# 49     AYE
# 50     AZO
# 51      BA
# 52     BAC
# 53     BAX
# 54    BBBY
# 55     BBT
# 56     BBY
# 57      BC
# 58     BCR
# 59     BDK
# 60     BDX
# 61    BEAM
# 62     BEN
# 63    BF.B
# 64    BHGE
# 65     BIG
# 66    BIIB
# 67     BJS
# 68      BK
# 69     BLL
# 70     BMC
# 71     BMS
# 72     BMY
# 73     BNI
# 74    BRCM
# 75     BRL
# 76     BSC
# 77     BSX
# 78   BTUUQ
# 79     BUD
# 80     BXP
# 81       C
# 82      CA
# 83     CAG
# 84     CAH
# 85     CAT
# 86      CB
# 87     CBE
# 88     CBH
# 89    CBRE
# 90     CBS
# 91     CCE
# 92     CCL
# 93   CCTYQ
# 94     CCU
# 95     CEG
# 96    CELG
# 97     CFC
# 98     CHK
# 99    CHRW
# 100     CI
# 101   CIEN
# 102   CINF
# 103  CITGQ
# 104     CL
# 105    CLX
# 106    CMA
# 107  CMCSA
# 108    CME
# 109    CMI
# 110    CMS
# 111    CNP
# 112    CNX
# 113    COF
# 114    COL
# 115    COP
# 116   COST
# 117    COV
# 118    CPB
# 119   CPWR
# 120   CSCO
# 121    CSX
# 122   CTAS
# 123    CTL
# 124   CTSH
# 125    CTX
# 126   CTXS
# 127    CVG
# 128    CVH
# 129    CVS
# 130    CVX
# 131      D
# 132     DD
# 133    DDR
# 134    DDS
# 135     DE
# 136   DELL
# 137     DF
# 138    DFS
# 139    DGX
# 140    DHI
# 141    DHR
# 142    DIS
# 143    DOV
# 144    DOW
# 145    DRI
# 146    DTE
# 147    DTV
# 148    DUK
# 149    DVN
# 150    DXC
# 151    DYN
# 152     EA
# 153   EBAY
# 154    ECL
# 155     ED
# 156    EDS
# 157    EFX
# 158    EIX
# 159  EKDKQ
# 160     EL
# 161    EMC
# 162    EMN
# 163    EMR
# 164    EOG
# 165     EP
# 166     EQ
# 167    EQR
# 168   ESRX
# 169    ESV
# 170   ETFC
# 171    ETN
# 172    ETR
# 173    EXC
# 174   EXPD
# 175   EXPE
# 176      F
# 177    FCX
# 178    FDO
# 179    FDX
# 180     FE
# 181    FHN
# 182    FII
# 183    FIS
# 184   FISV
# 185   FITB
# 186    FLR
# 187   FMCC
# 188   FNMA
# 189   FOXA
# 190    FRX
# 191    FTR
# 192    GAS
# 193     GD
# 194     GE
# 195   GENZ
# 196    GGP
# 197    GHC
# 198   GILD
# 199    GIS
# 200    GLW
# 201    GME
# 202    GNW
# 203  GOOGL
# 204    GPC
# 205    GPS
# 206     GR
# 207     GS
# 208     GT
# 209    GWW
# 210    HAL
# 211    HAR
# 212    HAS
# 213   HBAN
# 214   HCBK
# 215     HD
# 216    HES
# 217    HET
# 218    HIG
# 219    HNZ
# 220    HOG
# 221    HON
# 222    HOT
# 223    HPC
# 224    HPQ
# 225    HRB
# 226    HSH
# 227    HSP
# 228    HST
# 229    HSY
# 230    HUM
# 231    IAC
# 232    IBM
# 233    ICE
# 234    IFF
# 235    IGT
# 236   INTC
# 237   INTU
# 238     IP
# 239    IPG
# 240     IR
# 241    ITT
# 242    ITW
# 243   JAVA
# 244    JBL
# 245    JCI
# 246    JCP
# 247    JEC
# 248    JEF
# 249    JNJ
# 250   JNPR
# 251    JNS
# 252    JNY
# 253    JPM
# 254    JWN
# 255      K
# 256   KATE
# 257    KBH
# 258    KEY
# 259     KG
# 260    KIM
# 261   KLAC
# 262    KMB
# 263     KO
# 264     KR
# 265    KSS
# 266      L
# 267     LB
# 268    LEG
# 269  LEHMQ
# 270    LEN
# 271     LH
# 272    LLL
# 273   LLTC
# 274    LLY
# 275     LM
# 276    LMT
# 277    LNC
# 278    LOW
# 279    LSI
# 280    LUV
# 281    LXK
# 282      M
# 283    MAR
# 284    MAS
# 285    MAT
# 286    MBI
# 287    MCD
# 288   MCHP
# 289    MCK
# 290    MCO
# 291   MDLZ
# 292    MDP
# 293    MDT
# 294    MER
# 295    MET
# 296    MHS
# 297     MI
# 298    MIL
# 299    MKC
# 300    MMC
# 301    MMM
# 302     MO
# 303   MOLX
# 304    MON
# 305    MRK
# 306    MRO
# 307     MS
# 308   MSFT
# 309    MSI
# 310    MTB
# 311    MTG
# 312  MTLQQ
# 313    MTW
# 314     MU
# 315    MUR
# 316    MWV
# 317    MWW
# 318    MYL
# 319    NBL
# 320    NBR
# 321    NCC
# 322     NE
# 323    NEE
# 324    NEM
# 325     NI
# 326    NKE
# 327    NOC
# 328    NOV
# 329   NOVL
# 330    NSC
# 331    NSM
# 332   NTAP
# 333   NTRS
# 334    NUE
# 335   NVDA
# 336   NVLS
# 337    NWL
# 338    NYT
# 339    NYX
# 340    ODP
# 341    OMC
# 342    OMX
# 343   ORCL
# 344    OXY
# 345   PAYX
# 346    PBG
# 347    PBI
# 348   PCAR
# 349    PCG
# 350    PCL
# 351    PCP
# 352   PDCO
# 353    PEG
# 354    PEP
# 355    PFE
# 356    PFG
# 357     PG
# 358    PGN
# 359    PGR
# 360     PH
# 361    PHM
# 362    PKI
# 363    PLD
# 364    PLL
# 365    PNC
# 366    PNW
# 367    POM
# 368    PPG
# 369    PPL
# 370    PRU
# 371    PSA
# 372    PTV
# 373     PX
# 374      Q
# 375   QCOM
# 376   QLGC
# 377      R
# 378    RAI
# 379    RDC
# 380     RF
# 381    RHI
# 382    RIG
# 383     RL
# 384    ROH
# 385    ROK
# 386    RRC
# 387    RRD
# 388  RSHCQ
# 389    RTN
# 390     RX
# 391      S
# 392    SAF
# 393   SBUX
# 394   SCHW
# 395     SE
# 396    SEE
# 397    SGP
# 398   SHLD
# 399    SHW
# 400   SIAL
# 401    SII
# 402    SLB
# 403    SLM
# 404    SNA
# 405   SNDK
# 406    SNV
# 407     SO
# 408    SOV
# 409    SPG
# 410   SPGI
# 411   SPLS
# 412    SRE
# 413    SSP
# 414    STI
# 415    STJ
# 416    STR
# 417    STT
# 418    STZ
# 419    SUN
# 420  SUNEQ
# 421    SVU
# 422    SWK
# 423    SWY
# 424    SYK
# 425   SYMC
# 426    SYY
# 427      T
# 428    TAP
# 429    TDC
# 430     TE
# 431    TEG
# 432    TEL
# 433    TER
# 434    TEX
# 435   TGNA
# 436    TGT
# 437    THC
# 438    TIE
# 439    TIF
# 440    TJX
# 441   TLAB
# 442    TMK
# 443    TMO
# 444    TPR
# 445   TROW
# 446    TRV
# 447    TSN
# 448     TT
# 449    TWX
# 450    TXN
# 451    TXT
# 452    UIS
# 453    UNH
# 454    UNM
# 455    UNP
# 456    UPS
# 457    USB
# 458    UST
# 459    UTX
# 460    VAR
# 461    VFC
# 462   VIAB
# 463   VIAV
# 464    VLO
# 465    VMC
# 466    VNO
# 467   VRSN
# 468     VZ
# 469  WAMUQ
# 470    WAT
# 471     WB
# 472    WBA
# 473    WEN
# 474    WFC
# 475    WFM
# 476    WFT
# 477    WHR
# 478    WIN
# 479     WM
# 480    WMB
# 481    WMT
# 482     WU
# 483    WWY
# 484     WY
# 485    WYE
# 486   WYND
# 487      X
# 488    XEL
# 489     XL
# 490   XLNX
# 491    XOM
# 492    XRX
# 493    XTO
# 494    YUM
# 495    ZBH
# 496   ZION

# %%
df2.to_csv(r'C:\Users\yuxua\Desktop\Companies 2008.csv', index = False)

# %%
# Get current S&P500 list.
filename = 'sp500.csv'
current = pd.read_csv(filename)
current = sorted(list(current['Symbol']))
#print(current)

# %%
# Show what's been added and removed since snap_shot date.

added = list(set(current) - set(past))
print('*'*40, f'ADDED since {snap_shot}', '*'*40)
print(added)
print()

removed = list(set(past) - set(current))
print('*'*40, f'REMOVED since {snap_shot}', '*'*40)
print(removed)
# Out:
# **************************************** ADDED since 2008-01-01 ****************************************
# ['STX', 'TSCO', 'SJM', 'MTD', 'BR', 'CDW', 'VTR', 'DISH', 'LRCX', 'CZR', 'SNPS', 'CTRA', 'DAL', 'CRM', 'XRAY', 'ACGL', 'FDS', 'VRTX', 'CFG', 'EPAM', 'PM', 'ELV', 'REGN', 'XYL', 'BRO', 'SEDG', 'ISRG', 'KEYS', 'TDY', 'PODD', 'CPRT', 'TSLA', 'HRL', 'IRM', 'DPZ', 'UDR', 'FTNT', 'PAYC', 'AWK', 'ALLE', 'ES', 'FRC', 'EVRG', 'GNRC', 'IVZ', 'TRMB', 'MOH', 'FLT', 'NRG', 'OKE', 'ULTA', 'APTV', 'RCL', 'VTRS', 'CCI', 'CE', 'DXCM', 'WAB', 'RSG', 'IDXX', 'CNC', 'CBOE', 'ANET', 'ON', 'V', 'ALGN', 'BLK', 'MKTX', 'SYF', 'CSGP', 'BG', 'POOL', 'FOX', 'STLD', 'MPC', 'HLT', 'HSIC', 'STE', 'AVGO', 'LW', 'TDG', 'CRL', 'AOS', 'ZTS', 'BRK.B', 'MLM', 'HII', 'CDNS', 'FSLR', 'MOS', 'IT', 'LKQ', 'SBAC', 'NDAQ', 'SWKS', 'RTX', 'JKHY', 'GRMN', 'EQIX', 'NVR', 'O', 'IEX', 'AAP', 'BKR', 'JBHT', 'REG', 'PSX', 'CARR', 'WYNN', 'KMX', 'FICO', 'CTVA', 'URI', 'MA', 'GL', 'DG', 'MTCH', 'LNT', 'ARE', 'COO', 'ANSS', 'NXPI', 'CTLT', 'HOLX', 'IQV', 'WRB', 'LDOS', 'EQT', 'NWS', 'MRNA', 'TFC', 'DLR', 'BALL', 'NOW', 'GM', 'LYV', 'ABBV', 'CMG', 'DVA', 'ETSY', 'FMC', 'AJG', 'EXR', 'FANG', 'ORLY', 'CF', 'MPWR', 'VICI', 'CDAY', 'BKNG', 'PYPL', 'MHK', 'GEN', 'DLTR', 'ENPH', 'OGN', 'TTWO', 'BBWI', 'BIO', 'WST', 'TYL', 'PXD', 'AMCR', 'WTW', 'TFX', 'ALK', 'LVS', 'ROST', 'GOOG', 'PARA', 'OTIS', 'ROP', 'KHC', 'RJF', 'PNR', 'CPT', 'LIN', 'QRVO', 'PTC', 'MGM', 'TRGP', 'BWA', 'UHS', 'J', 'AAL', 'ZBRA', 'VRSK', 'TMUS', 'APH', 'NFLX', 'WRK', 'PWR', 'HWM', 'ATO', 'MNST', 'WELL', 'ACN', 'LYB', 'WEC', 'CHTR', 'WBD', 'HCA', 'NCLH', 'FAST', 'KDP', 'LHX', 'INCY', 'AME', 'NDSN', 'KMI', 'PEAK', 'CHD', 'INVH', 'FFIV', 'ODFL', 'GEHC', 'ILMN', 'FTV', 'FRT', 'RMD', 'UAL', 'ESS', 'PKG', 'TECH', 'GPN', 'ATVI', 'EW', 'NWSA', 'RE', 'MAA', 'WDC', 'ALB', 'HPE', 'MSCI', 'META', 'ROL']
#
# **************************************** REMOVED since 2008-01-01 ****************************************
# ['AVP', 'BJS', 'XRX', 'DDS', 'FTR', 'JCP', 'ANF', 'KSS', 'MTW', 'GAS', 'JAVA', 'TLAB', 'TWX', 'CTX', 'GME', 'MON', 'WEN', 'PLL', 'XTO', 'EMC', 'STJ', 'MUR', 'ACS', 'EQ', 'NBL', 'PX', 'PGN', 'ODP', 'SIAL', 'RIG', 'ABI', 'ARNC', 'CCU', 'RAI', 'TEG', 'LLL', 'BNI', 'TGNA', 'PBI', 'MOLX', 'UTX', 'WAMUQ', 'COL', 'EP', 'WYE', 'HNZ', 'ANTM', 'PCL', 'WIN', 'XL', 'PDCO', 'SAF', 'SYMC', 'BLL', 'UNM', 'AIV', 'CVH', 'BUD', 'JWN', 'APOL', 'MTLQQ', 'FRX', 'WB', 'SUN', 'TIE', 'BCR', 'TEX', 'BC', 'MTG', 'CBE', 'NYX', 'TIF', 'APC', 'SVU', 'CTXS', 'SNV', 'SSP', 'DYN', 'CTL', 'THC', 'LM', 'NE', 'WWY', 'SNDK', 'X', 'SPLS', 'GHC', 'BHGE', 'JNS', 'BRL', 'AW', 'VIAB', 'ANDV', 'ESV', 'CA', 'HOG', 'ITT', 'LSI', 'HPC', 'QLGC', 'SII', 'GENZ', 'ROH', 'NVLS', 'RRC', 'RSHCQ', 'S', 'LEHMQ', 'GT', 'BDK', 'BEAM', 'MYL', 'STI', 'GR', 'LLTC', 'ETFC', 'MBI', 'CITGQ', 'FII', 'CIEN', 'HET', 'SOV', 'KATE', 'MDP', 'RX', 'HCBK', 'TMK', 'JBL', 'IGT', 'STR', 'CELG', 'RDC', 'LXK', 'HSH', 'ATI', 'KG', 'SWY', 'LEG', 'M', 'CCE', 'UIS', 'FDO', 'ESRX', 'JEC', 'TDC', 'PCP', 'FHN', 'CPWR', 'MWW', 'JNY', 'HSP', 'HOT', 'ALTR', 'POM', 'DELL', 'RRD', 'BMS', 'NCC', 'SHLD', 'ACAS', 'AET', 'WFM', 'MER', 'OMX', 'MHS', 'GNW', 'JEF', 'CBH', 'DTV', 'VAR', 'VNO', 'PBG', 'CBS', 'ASH', 'Q', 'AABA', 'CVG', 'BBBY', 'MAT', 'UST', 'SUNEQ', 'NSM', 'PTV', 'WFT', 'FMCC', 'GPS', 'DF', 'LB', 'NOVL', 'DDR', 'TE', 'SE', 'MIL', 'AYE', 'IAC', 'MWV', 'R', 'BIG', 'NOV', 'EKDKQ', 'CFC', 'AN', 'GGP', 'CCTYQ', 'BSC', 'FLR', 'FNMA', 'COV', 'BTUUQ', 'BRCM', 'VIAV', 'BBT', 'HRB', 'XLNX', 'KBH', 'CNX', 'AGN', 'CHK', 'WU', 'BMC', 'NYT', 'SGP', 'EDS', 'NBR', 'HAR', 'WYND', 'RTN', 'ABKFQ', 'SLM', 'MI']
